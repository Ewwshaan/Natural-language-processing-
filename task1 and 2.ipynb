# %%
import nltk

# %% [markdown]
# task1

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories='news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
inaugural.words(fileids='2009-Obama.txt')
# Out:
# ['My', 'fellow', 'citizens', ':', 'I', 'stand', 'here', ...]

# %%
inaugural.words(fileids='1865-Lincoln.txt')[:20]
# Out:
# ['Fellow',
#  '-',
#  'Countrymen',
#  ':',
#  'At',
#  'this',
#  'second',
#  'appearing',
#  'to',
#  'take',
#  'the',
#  'oath',
#  'of',
#  'the',
#  'Presidential',
#  'office',
#  'there',
#  'is',
#  'less',
#  'occasion']

# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords

# %%
word_string = ' '.join(inaugural.words(fileids='2021-Biden.txt'))

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
wordCloud = WordCloud(stopwords=STOPWORDS, background_color='white', width=1200, height=1000).generate(word_string)

# %%
plt.figure(figsize=(15, 10))
plt.clf()
plt.imshow(wordCloud)
plt.axis('off')
plt.show()

# %%
brown.words(categories='adventure')[:50]
# Out:
# ['Dan',
#  'Morgan',
#  'told',
#  'himself',
#  'he',
#  'would',
#  'forget',
#  'Ann',
#  'Turner',
#  '.',
#  'He',
#  'was',
#  'well',
#  'rid',
#  'of',
#  'her',
#  '.',
#  'He',
#  'certainly',
#  "didn't",
#  'want',
#  'a',
#  'wife',
#  'who',
#  'was',
#  'fickle',
#  'as',
#  'Ann',
#  '.',
#  'If',
#  'he',
#  'had',
#  'married',
#  'her',
#  ',',
#  "he'd",
#  'have',
#  'been',
#  'asking',
#  'for',
#  'trouble',
#  '.',
#  'But',
#  'all',
#  'of',
#  'this',
#  'was',
#  'rationalization',
#  '.',
#  'Sometimes']

# %%
text1 ='The tragedy of old age is not that one is old, but that one is young.'
fd = nltk.FreqDist(text1.split())
fd
# Out:
# FreqDist({'is': 3, 'that': 2, 'one': 2, 'The': 1, 'tragedy': 1, 'of': 1, 'old': 1, 'age': 1, 'not': 1, 'old,': 1, ...})
